# %% [markdown]
# <a href="https://colab.research.google.com/github/latisa-29/KKA-Latisa-/blob/main/KKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = 10
angka = 12,5
teks = "Hallo SigmaSix"
contoh_list = [1, 2, 3, 4, 5]

print(a)
print(angka)
print(teks)
print(contoh_list)
# Out:
# 10
# (12, 5)
# Hallo SigmaSix
# [1, 2, 3, 4, 5]
